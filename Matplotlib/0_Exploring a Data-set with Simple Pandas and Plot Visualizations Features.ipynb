# %% [markdown]
# # About

# %%
import pandas as pd

# %%
world = pd.read_csv('Tennis_World_Number_1s.csv')

# %%
world
# Out:
#           Tennis_Player  Total_Weeks_at_No_1  \
# 0         Roger Federer                  310
# 1          Pete Sampras                  286
# 2            Ivan Lendl                  270
# 3         Jimmy Connors                  268
# 4        Novak Djokovic                  264
# 5          Rafael Nadal                  196
# 6          John McEnroe                  170
# 7            Bjorn Borg                  109
# 8          Andre Agassi                  101
# 9        Lleyton Hewitt                   80
# 10        Stefan Edberg                   72
# 11          Jim Courier                   58
# 12      Gustavo Kuerten                   43
# 13          Andy Murray                   41
# 14         Ilie Nastase                   40
# 15        Mats Wilander                   20
# 16         Andy Roddick                   13
# 17         Boris Becker                   12
# 18          Marat Safin                    9
# 19  Juan Carlos Ferrero                    8
# 20        John Newcombe                    8
# 21   Yevgeny Kafelnikov                    6
# 22        Thomas Muster                    6
# 23         Marcelo Rios                    6
# 24          Carlos Moya                    2
# 25       Patrick Rafter                    1
#
#     Maximum_Consectutive_Weeks_at_no_1  Years_End_no_1 Careers_Wins_Losses  \
# 0                                  237               5            1222-265
# 1                                  102               6             762-222
# 2                                  157               4            1068-242
# 3                                  160               5            1274-282
# 4                                  122               5             871-182
# 5                                   56               4             960-196
# 6                                   58               4             881-198
# 7                                   46               2             644-135
# 8                                   52               1             870-274
# 9                                   75               2             616-262
# 10                                  24               2             801-270
# 11                                  27               1             506-237
# 12                                  30               1             358-195
# 13                                  41               1             663-191
# 14                                  40               1             858-320
# 15                                  20               1             571-222
# 16                                  13               1             612-213
# 17                                   9               0             713-214
# 18                                   4               0             422-267
# 19                                   8               0             479-262
# 20                                   8               0             552-198
# 21                                   6               0             609-306
# 22                                   5               0             625-273
# 23                                   4               0             391-192
# 24                                   2               0             575-319
# 25                                   1               0             358-191
#
#     Titles  Prize_Money  Unnamed: 7
# 0      102    126266005         NaN
# 1       64     43280489         NaN
# 2       94     21262417         NaN
# 3      109      8641040         NaN
# 4       75    134684000         NaN
# 5       83    111328858         NaN
# 6       77     12552132         NaN
# 7       64      3655751         NaN
# 8       60     31152975         NaN
# 9       30     20879934         NaN
# 10      41     20630941         NaN
# 11      23     14034132         NaN
# 12      20     14807000         NaN
# 13      45     61217017         NaN
# 14      59      2076761         NaN
# 15      33      7956101         NaN
# 16      32     20640030         NaN
# 17      49     25080956         NaN
# 18      15     14373291         NaN
# 19      16     13998165         NaN
# 20      35      1062408         NaN
# 21      26     23883797         NaN
# 22      44     12266977         NaN
# 23      18      9713771         NaN
# 24      20     13443970         NaN
# 25      11     11133128         NaN

# %%
world.drop('Unnamed: 7',axis=1,inplace=True)

# %% [markdown]
# ## Get an overview of the dataset

# %%
world.columns
# Out:
# Index(['Tennis_Player', 'Total_Weeks_at_No_1',
#        'Maximum_Consectutive_Weeks_at_no_1', 'Years_End_no_1',
#        'Careers_Wins_Losses', 'Titles', 'Prize_Money'],
#       dtype='object')

# %%
world.isna().sum()
# Out:
# Tennis_Player                         0
# Total_Weeks_at_No_1                   0
# Maximum_Consectutive_Weeks_at_no_1    0
# Years_End_no_1                        0
# Careers_Wins_Losses                   0
# Titles                                0
# Prize_Money                           0
# dtype: int64

# %%
world.dtypes
# Out:
# Tennis_Player                         object
# Total_Weeks_at_No_1                    int64
# Maximum_Consectutive_Weeks_at_no_1     int64
# Years_End_no_1                         int64
# Careers_Wins_Losses                   object
# Titles                                 int64
# Prize_Money                            int64
# dtype: object

# %% [markdown]
# # Who is the best former world number 1?
# * the dataset has info that can be used to decide who may be the best former world number 1
#     * e.g. determine who has the highest win percentage
# *  we can use the careers_wins_losses
#     * split into 2 separate columns

# %%
world[['Career_Wins','Career_losses']] = world.Careers_Wins_Losses.str.split('-',expand=True).astype(float)

# %%
world[['Tennis_Player','Careers_Wins_Losses','Career_Wins','Career_losses']].head()
# Out:
#     Tennis_Player Careers_Wins_Losses  Career_Wins  Career_losses
# 0   Roger Federer            1222-265       1222.0          265.0
# 1    Pete Sampras             762-222        762.0          222.0
# 2      Ivan Lendl            1068-242       1068.0          242.0
# 3   Jimmy Connors            1274-282       1274.0          282.0
# 4  Novak Djokovic             871-182        871.0          182.0
